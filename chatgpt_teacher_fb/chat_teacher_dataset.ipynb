# %%
# prompt: load the chat_gpt teachers spreadsheet in my google drive into a dataframe

import pandas as pd
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')

# Specify the path to your spreadsheet
spreadsheet_path = '/content/drive/My Drive/chat_teacher_data.xlsx'

# Read the spreadsheet into a DataFrame
df = pd.read_excel(spreadsheet_path)

# Print the DataFrame
#print(df)
df.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   w                         172 non-null    object
#  1   NUMBER OF LIKES           172 non-null    object
#  2   ONE SENTENCE DESCRIPTION  172 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
# prompt: show the field names in this dataframe

print(df.columns)
# Out:
# Index(['w', 'NUMBER OF LIKES', 'ONE SENTENCE DESCRIPTION'], dtype='object')
